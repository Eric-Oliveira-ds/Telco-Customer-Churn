# %% [markdown]
# # Extract data from Telco database and making a dictionary data information

# %% [markdown]
# ## Libs

# %%
import pandas as pd
pd.set_option('display.max.columns',50)

# %% [markdown]
# ## Extraction

# %%
# path to read specific csv data
path = r'C:\Users\erico\Documents\projeto-churn\Telco-Customer-Churn\data\WA_Fn-UseC_-Telco-Customer-Churn.csv'

# %%
df_teste = pd.read_csv(path)

# %%
df_teste['TotalCharges'] = df_teste['TotalCharges'].apply(lambda x: float(x.replace(' ', '0')))
df_teste['SeniorCitizen'] = df_teste['SeniorCitizen'].map({0:'No',1:'Yes'})
df_teste = df_teste.set_index(['customerID']).copy()
df_teste.drop(['gender','PhoneService','Churn'], inplace=True, axis=1)

# %%
df_teste.to_csv(r'C:\Users\erico\Documents\projeto-churn\Telco-Customer-Churn\data\teste_prod.csv')

# %%
# create a function to read data from the company
import pandas as pd

def read_data(data_path:str)-> pd.DataFrame:

    """ Funtion - Read csv file from path 
    and tranform column and save to parquet 

        Receive:
            data_path - path by csv data
        Return: 
            dataframe pandas
    """
    
    df = pd.read_csv(data_path)

    df['TotalCharges'] = df['TotalCharges'].apply(lambda x: float(x.replace(' ', '0')))
    df['SeniorCitizen'] = df['SeniorCitizen'].map({0:'No',1:'Yes'})

    df.to_parquet(r'C:\Users\erico\Documents\projeto-churn\Telco-Customer-Churn\data\curated_data.parquet')

    dataframe = pd.read_parquet(r'C:\Users\erico\Documents\projeto-churn\Telco-Customer-Churn\data\curated_data.parquet')

    return dataframe

# %%
df = read_data(path)

# %%
df.head()
# Out:
#    customerID  gender SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female            No     Yes         No       1           No
# 1  5575-GNVDE    Male            No      No         No      34          Yes
# 2  3668-QPYBK    Male            No      No         No       2          Yes
# 3  7795-CFOCW    Male            No      No         No      45           No
# 4  9237-HQITU  Female            No      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
# 2                No             DSL            Yes          Yes
# 3  No phone service             DSL            Yes           No
# 4                No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# ...

# %% [markdown]
#  - Function created and validated
#     - next steps is make a Python file with the function in scripts directory

# %%
# config path scripts
sys.path.insert(0, r'C:\Users\erico\Documents\projeto-churn\Telco-Customer-Churn\scripts')

# %%
from extract_data import read_data

# %%
# testing function
df = read_data(path)

# %%
df.head()
# Out:
#    customerID  gender SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female            No     Yes         No       1           No
# 1  5575-GNVDE    Male            No      No         No      34          Yes
# 2  3668-QPYBK    Male            No      No         No       2          Yes
# 3  7795-CFOCW    Male            No      No         No      45           No
# 4  9237-HQITU  Female            No      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
# 2                No             DSL            Yes          Yes
# 3  No phone service             DSL            Yes           No
# 4                No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# ...

# %%
df.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %% [markdown]
# # Dictionary of database

# %% [markdown]
# [Gsheet](https://docs.google.com/spreadsheets/d/1k2MHdiarHP7FcX-i4NZF1Q5KPVj9Td7DiEQiQI0gpJI/edit#gid=0)
